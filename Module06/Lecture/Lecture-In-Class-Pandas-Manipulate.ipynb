# %% [markdown]
# # Pandas (documentation reference in *Help* tab)
#
# * Open source library build on numpy library
# * Allows for data analysis, cleaning, and preperation
# * Provides built in visual features
# * Many data formats can be used with it
# * Alot like a suped up excel

# %% [markdown]
# # Importing Pandas

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

import pandas as pd

# %% [markdown]
# # Pandas Series
#
# Pandas is a python object similar to:

# %%
# 4 python objects
labels = ['a','b','c']
my_data = [10,20,30]
array = np.array(my_data)
d = {'a':10, 'b':20, 'c':30}

print(type(labels))
print(type(my_data))
print(type(array))
print(type(d))
# Out:
# <class 'list'>
# <class 'list'>
# <class 'numpy.ndarray'>
# <class 'dict'>

# %% [markdown]
# We can use a series by calling
# > pd.Series(data,labels)
#
# from our pandas object, where data is a data array and labels are the row names. **Note the capital 'S' in 'Series'**
#
# ## <span style="color:red"> In Class </span>
#
# Create a pandas series named ser1 that uses the array 'my_data' and 'labels' defined in the cell above

# %%
ser1 = pd.Series(my_data, labels) #put code here
print(ser1)
print(type(ser1))
# Out:
# a    10
# b    20
# c    30
# dtype: int64
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Assessing a specific element in a Series can be done in two ways

# %%
print('1:', ser1['c'])
# or
print('2:',ser1.c)
# Out:
# 1: 30
# 2: 30

# %% [markdown]
# We can add series

# %%
#create two series
ser1 = pd.Series([1,2,3],['a','b','c'])
ser2 = pd.Series([1,2,4],['a','b','d'])

print('ser1:\n',ser1)
print('\n')
print('ser2:\n',ser2)
print('\n')
print('sum:\n',ser1 + ser2)
# Out:
# ser1:
#  a    1
# b    2
# c    3
# dtype: int64
#
#
# ser2:
#  a    1
# b    2
# d    4
# dtype: int64
#
#
# sum:
#  a    2.0
# b    4.0
# c    NaN
# d    NaN
# dtype: float64

# %% [markdown]
# # Pandas DataFrames
#
# ## A DataFrame is a set of pandas Series that share a common index
# Create a DataFrame object by calling
# >pandas.DataFrame(data,index,column)
#
# * Takes data and index inforamtion just like a pandas Series
# * Each column is a pandas Series with common index

# %% [markdown]
# ## Importing data into a DataFrame
# Pandas can read in many data formats
# - CSV
# - JASON
# - Excel
# - Pickle
# - SQL
# - XML
# - ...

# %%
# %ls
# Out:
# In-Class-Pandas-Manipulate-Solution.ipynb
# In-Class-Pandas-Manipulate.ipynb
# Lecture-Pandas-Visualization.ipynb
# groupby.png
# sunspot_data.csv

# %%
inpath = %pwd
print(inpath)
infile = inpath +'/sunspot_data.csv'
print(infile)
#df = pd.read_csv()
# Out:
# /Users/matt/Desktop/Dropbox/Teaching/3511/Fall2022/Module6/Participation
# /Users/matt/Desktop/Dropbox/Teaching/3511/Fall2022/Module6/Participation/sunspot_data.csv

# %%
df = pd.read_csv(infile)

# %%
# -1 = no data taken
df
# Out:
#        Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  \
# 0               0  1818      1    1                  1818.001
# 1               1  1818      1    2                  1818.004
# 2               2  1818      1    3                  1818.007
# 3               3  1818      1    4                  1818.010
# 4               4  1818      1    5                  1818.012
# ...           ...   ...    ...  ...                       ...
# 73713       73713  2019     10   27                  2019.821
# 73714       73714  2019     10   28                  2019.823
# 73715       73715  2019     10   29                  2019.826
# 73716       73716  2019     10   30                  2019.829
# 73717       73717  2019     10   31                  2019.832
#
#        Number of Sunspots  Standard Deviation  Observations  Indicator
# 0                      -1                -1.0             0          1
# 1                      -1                -1.0             0          1
# 2                      -1                -1.0             0          1
# 3                      -1                -1.0             0          1
# 4                      -1                -1.0             0          1
# ...                   ...                 ...           ...        ...
# 73713                   0                 0.0            34          0
# 73714                   0                 0.0            34          0
# 73715                   0                 0.0            30          0
# 73716                   0                 0.0            24          0
# 73717                   0                 0.0            28          0
#
# [73718 rows x 9 columns]

# %% [markdown]
# ## Investigating information in DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73718 entries, 0 to 73717
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                73718 non-null  int64
#  1   Year                      73718 non-null  int64
#  2   Month                     73718 non-null  int64
#  3   Day                       73718 non-null  int64
#  4   Date In Fraction Of Year  73718 non-null  float64
#  5   Number of Sunspots        73718 non-null  int64
#  6   Standard Deviation        73718 non-null  float64
#  7   Observations              73718 non-null  int64
#  8   Indicator                 73718 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 5.1 MB

# %%
df.describe()
# Out:
#          Unnamed: 0          Year         Month           Day  \
# count  73718.000000  73718.000000  73718.000000  73718.000000
# mean   36858.500000   1918.416750      6.518896     15.729347
# std    21280.697909     58.264401      3.447114      8.800032
# min        0.000000   1818.000000      1.000000      1.000000
# 25%    18429.250000   1868.000000      4.000000      8.000000
# 50%    36858.500000   1918.000000      7.000000     16.000000
# 75%    55287.750000   1969.000000     10.000000     23.000000
# max    73717.000000   2019.000000     12.000000     31.000000
#
#        Date In Fraction Of Year  Number of Sunspots  Standard Deviation  \
# count              73718.000000        73718.000000        73718.000000
# mean                1918.916406           79.248732            6.924587
# std                   58.264520           77.470942            4.778793
# min                 1818.001000           -1.000000           -1.000000
# 25%                 1868.458500           15.000000            3.000000
# 50%                 1918.917500           58.000000            6.600000
# 75%                 1969.373250          125.000000           10.000000
# max                 2019.832000          528.000000           77.700000
#
#        Observations     Indicator
# count  73718.000000  73718.000000
# mean       4.429678      0.998331
# std        7.884112      0.040814
# min        0.000000      0.000000
# 25%        1.000000      1.000000
# 50%        1.000000      1.000000
# 75%        1.000000      1.000000
# max       60.000000      1.000000

# %%
df.head(5)
# Out:
#    Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  Number of Sunspots  \
# 0           0  1818      1    1                  1818.001                  -1
# 1           1  1818      1    2                  1818.004                  -1
# 2           2  1818      1    3                  1818.007                  -1
# 3           3  1818      1    4                  1818.010                  -1
# 4           4  1818      1    5                  1818.012                  -1
#
#    Standard Deviation  Observations  Indicator
# 0                -1.0             0          1
# 1                -1.0             0          1
# 2                -1.0             0          1
# 3                -1.0             0          1
# 4                -1.0             0          1

# %%
df.tail(1)
# Out:
#        Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  \
# 73717       73717  2019     10   31                  2019.832
#
#        Number of Sunspots  Standard Deviation  Observations  Indicator
# 73717                   0                 0.0            28          0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73718 entries, 0 to 73717
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                73718 non-null  int64
#  1   Year                      73718 non-null  int64
#  2   Month                     73718 non-null  int64
#  3   Day                       73718 non-null  int64
#  4   Date In Fraction Of Year  73718 non-null  float64
#  5   Number of Sunspots        73718 non-null  int64
#  6   Standard Deviation        73718 non-null  float64
#  7   Observations              73718 non-null  int64
#  8   Indicator                 73718 non-null  int64
# dtypes: float64(2), int64(7)
# memory usage: 5.1 MB

# %%
print(df.Year)
print('\n')
print(df['Year'])
#print(df[df['Number of Sunspots'] > 0].count())
# Out:
# 0        1818
# 1        1818
# 2        1818
# 3        1818
# 4        1818
#          ...
# 73713    2019
# 73714    2019
# 73715    2019
# 73716    2019
# 73717    2019
# Name: Year, Length: 73718, dtype: int64
#
#
# 0        1818
# 1        1818
# 2        1818
# 3        1818
# 4        1818
#          ...
# 73713    2019
# 73714    2019
# 73715    2019
# 73716    2019
# 73717    2019
# Name: Year, Length: 73718, dtype: int64

# %% [markdown]
# Print mulitle columns:

# %%
df[ ['Year','Number of Sunspots'] ]
# Out:
#        Year  Number of Sunspots
# 0      1818                  -1
# 1      1818                  -1
# 2      1818                  -1
# 3      1818                  -1
# 4      1818                  -1
# ...     ...                 ...
# 73713  2019                   0
# 73714  2019                   0
# 73715  2019                   0
# 73716  2019                   0
# 73717  2019                   0
#
# [73718 rows x 2 columns]

# %% [markdown]
# Dataframes are collections of Pandas Series

# %%
print(type(df))
print(type(df.Year))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %% [markdown]
# Access specific entries in a column:

# %%
print(df.Year[50000])
# Out:
# 1954

# %% [markdown]
# Access specific entries in a row:
# - iloc -- row index
# - loc -- row name

# %%
df.head(5)
# Out:
#    Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  Number of Sunspots  \
# 0           0  1818      1    1                  1818.001                  -1
# 1           1  1818      1    2                  1818.004                  -1
# 2           2  1818      1    3                  1818.007                  -1
# 3           3  1818      1    4                  1818.010                  -1
# 4           4  1818      1    5                  1818.012                  -1
#
#    Standard Deviation  Observations  Indicator
# 0                -1.0             0          1
# 1                -1.0             0          1
# 2                -1.0             0          1
# 3                -1.0             0          1
# 4                -1.0             0          1

# %%
print(df.loc[1,'Day'])
print('\n')
print(df.loc[1]['Day'])
# Out:
# 2
#
#
# 2.0

# %%
df.iloc[1]
# Out:
# Unnamed: 0                     1.000
# Year                        1818.000
# Month                          1.000
# Day                            2.000
# Date In Fraction Of Year    1818.004
# Number of Sunspots            -1.000
# Standard Deviation            -1.000
# Observations                   0.000
# Indicator                      1.000
# Name: 1, dtype: float64

# %%
df.iloc[1,3]
# Out:
# 2

# %%
df.loc[[0,1,3],['Year','Number of Sunspots']]
# Out:
#    Year  Number of Sunspots
# 0  1818                  -1
# 1  1818                  -1
# 3  1818                  -1

# %% [markdown]
# ## <span style="color:red"> In Class </span>
#
# Use 'loc' to print the 'Year, Number of Sunspots, and Observations' for rows 500, 1000, and 1500

# %%
df.loc[[500,1000,1500],['Year','Number of Sunspots','Observations']]  #put code here
# Out:
#       Year  Number of Sunspots  Observations
# 500   1819                  42             1
# 1000  1820                   0             1
# 1500  1822                   0             1

# %% [markdown]
# ## Remove Rows and Columns

# %%
df
# Out:
#        Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  \
# 0               0  1818      1    1                  1818.001
# 1               1  1818      1    2                  1818.004
# 2               2  1818      1    3                  1818.007
# 3               3  1818      1    4                  1818.010
# 4               4  1818      1    5                  1818.012
# ...           ...   ...    ...  ...                       ...
# 73713       73713  2019     10   27                  2019.821
# 73714       73714  2019     10   28                  2019.823
# 73715       73715  2019     10   29                  2019.826
# 73716       73716  2019     10   30                  2019.829
# 73717       73717  2019     10   31                  2019.832
#
#        Number of Sunspots  Standard Deviation  Observations  Indicator
# 0                      -1                -1.0             0          1
# 1                      -1                -1.0             0          1
# 2                      -1                -1.0             0          1
# 3                      -1                -1.0             0          1
# 4                      -1                -1.0             0          1
# ...                   ...                 ...           ...        ...
# 73713                   0                 0.0            34          0
# 73714                   0                 0.0            34          0
# 73715                   0                 0.0            30          0
# 73716                   0                 0.0            24          0
# 73717                   0                 0.0            28          0
#
# [73718 rows x 9 columns]

# %% [markdown]
# To remove columns we can use Drop()
# - Note the 'axis not found' error that this produces
# - This is because by default pandas uses axis = 0 (rows) for the drop function
# - There is no 'Date In Fraction Of Year' row
# - Change to column by setting axis = 1

# %%
df.drop('Date In Fraction Of Year')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 df.drop('Date In Fraction Of Year')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
#    4818     Drop specified labels from rows or columns.
#    4819
#    (...)
#    4952             weight  1.0     0.8
#    4953     """
# -> 4954     return super().drop(
#    4955         labels=labels,
#    4956         axis=axis,
#    4957         index=index,
#    4958         columns=columns,
#    4959         level=level,
#    4960         inplace=inplace,
#    4961         errors=errors,
#    4962     )
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['Date In Fraction Of Year'] not found in axis"

# %%
df.drop('Date In Fraction Of Year',axis=1)
# Out:
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 0               0  1818      1    1                  -1                -1.0
# 1               1  1818      1    2                  -1                -1.0
# 2               2  1818      1    3                  -1                -1.0
# 3               3  1818      1    4                  -1                -1.0
# 4               4  1818      1    5                  -1                -1.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
#        Observations  Indicator
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 73713            34          0
# 73714            34          0
# 73715            30          0
# 73716            24          0
# 73717            28          0
#
# [73718 rows x 8 columns]

# %% [markdown]
# Our dataframe df does not retain the modification by default, we must tell pandas we want to keep this change by setting the paramter
# > inplace = True

# %%
df
# Out:
#        Unnamed: 0  Year  Month  Day  Date In Fraction Of Year  \
# 0               0  1818      1    1                  1818.001
# 1               1  1818      1    2                  1818.004
# 2               2  1818      1    3                  1818.007
# 3               3  1818      1    4                  1818.010
# 4               4  1818      1    5                  1818.012
# ...           ...   ...    ...  ...                       ...
# 73713       73713  2019     10   27                  2019.821
# 73714       73714  2019     10   28                  2019.823
# 73715       73715  2019     10   29                  2019.826
# 73716       73716  2019     10   30                  2019.829
# 73717       73717  2019     10   31                  2019.832
#
#        Number of Sunspots  Standard Deviation  Observations  Indicator
# 0                      -1                -1.0             0          1
# 1                      -1                -1.0             0          1
# 2                      -1                -1.0             0          1
# 3                      -1                -1.0             0          1
# 4                      -1                -1.0             0          1
# ...                   ...                 ...           ...        ...
# 73713                   0                 0.0            34          0
# 73714                   0                 0.0            34          0
# 73715                   0                 0.0            30          0
# 73716                   0                 0.0            24          0
# 73717                   0                 0.0            28          0
#
# [73718 rows x 9 columns]

# %%
df.drop('Date In Fraction Of Year',axis=1,inplace=True)

# %%
df
# Out:
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 0               0  1818      1    1                  -1                -1.0
# 1               1  1818      1    2                  -1                -1.0
# 2               2  1818      1    3                  -1                -1.0
# 3               3  1818      1    4                  -1                -1.0
# 4               4  1818      1    5                  -1                -1.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
#        Observations  Indicator
# 0                 0          1
# 1                 0          1
# 2                 0          1
# 3                 0          1
# 4                 0          1
# ...             ...        ...
# 73713            34          0
# 73714            34          0
# 73715            30          0
# 73716            24          0
# 73717            28          0
#
# [73718 rows x 8 columns]

# %% [markdown]
# # <span style="color:red">In Class</span>
#  Drop the columns 'Observations' and 'Indicator' from our dataframe df and have it retain those changes.

# %%
#put code here
df.drop(['Observations','Indicator'],axis=1,inplace=True)

# %%
df
# Out:
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 0               0  1818      1    1                  -1                -1.0
# 1               1  1818      1    2                  -1                -1.0
# 2               2  1818      1    3                  -1                -1.0
# 3               3  1818      1    4                  -1                -1.0
# 4               4  1818      1    5                  -1                -1.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
# [73718 rows x 6 columns]

# %% [markdown]
# ## NAN
#
# Many times data will have 'NA' or 'NAN' values (not a number). Pandas can deal with these via
# > dropna()
#
# This drops all rows that have a NA value in them
#
# We can also replace the NA values with another value of our choosing using
# > fillna()
#
# This will fill the value with any string, integer, float we give it.

# %% [markdown]
# # Conditionals

# %%
df.head(10)
# Out:
#    Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 0           0  1818      1    1                  -1                -1.0
# 1           1  1818      1    2                  -1                -1.0
# 2           2  1818      1    3                  -1                -1.0
# 3           3  1818      1    4                  -1                -1.0
# 4           4  1818      1    5                  -1                -1.0
# 5           5  1818      1    6                  -1                -1.0
# 6           6  1818      1    7                  -1                -1.0
# 7           7  1818      1    8                  65                10.2
# 8           8  1818      1    9                  -1                -1.0
# 9           9  1818      1   10                  -1                -1.0

# %% [markdown]
# Remove rows with Number of Sunspots = -1

# %%
df[ df['Number of Sunspots'] >= 0].head(10)
# Out:
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 7            7  1818      1    8                  65                10.2
# 12          12  1818      1   13                  37                 7.7
# 16          16  1818      1   17                  77                11.1
# 17          17  1818      1   18                  98                12.6
# 18          18  1818      1   19                 105                13.0
# 24          24  1818      1   25                  25                 6.3
# 27          27  1818      1   28                  38                 7.8
# 28          28  1818      1   29                  20                 5.7
# 33          33  1818      2    3                  17                 5.2
# 35          35  1818      2    5                  20                 5.7

# %%
df.head(10)
# Out:
#    Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 0           0  1818      1    1                  -1                -1.0
# 1           1  1818      1    2                  -1                -1.0
# 2           2  1818      1    3                  -1                -1.0
# 3           3  1818      1    4                  -1                -1.0
# 4           4  1818      1    5                  -1                -1.0
# 5           5  1818      1    6                  -1                -1.0
# 6           6  1818      1    7                  -1                -1.0
# 7           7  1818      1    8                  65                10.2
# 8           8  1818      1    9                  -1                -1.0
# 9           9  1818      1   10                  -1                -1.0

# %% [markdown]
# By default, pandas does not save the data frame with the conditional applied. To have changes stay we need to reasign the value of our data frame or save the outcome as a new data frame

# %%
df = df[df['Number of Sunspots'] >= 0]
new_df = df[df['Number of Sunspots'] >= 0]

# %%
df.head(10)
# Out:
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 7            7  1818      1    8                  65                10.2
# 12          12  1818      1   13                  37                 7.7
# 16          16  1818      1   17                  77                11.1
# 17          17  1818      1   18                  98                12.6
# 18          18  1818      1   19                 105                13.0
# 24          24  1818      1   25                  25                 6.3
# 27          27  1818      1   28                  38                 7.8
# 28          28  1818      1   29                  20                 5.7
# 33          33  1818      2    3                  17                 5.2
# 35          35  1818      2    5                  20                 5.7

# %%
new_df.head(10)
# Out:
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 7            7  1818      1    8                  65                10.2
# 12          12  1818      1   13                  37                 7.7
# 16          16  1818      1   17                  77                11.1
# 17          17  1818      1   18                  98                12.6
# 18          18  1818      1   19                 105                13.0
# 24          24  1818      1   25                  25                 6.3
# 27          27  1818      1   28                  38                 7.8
# 28          28  1818      1   29                  20                 5.7
# 33          33  1818      2    3                  17                 5.2
# 35          35  1818      2    5                  20                 5.7

# %% [markdown]
# ## Multiple Conditionals
# Say we want to keep rows where the number of sunspots observed are between 25 and 50

# %%
df.head(10)
df[ df['Number of Sunspots'] > 25 and df['Number of Sunspots'] < 50]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [53], in <cell line: 2>()
#       1 df.head(10)
# ----> 2 df[ df['Number of Sunspots'] > 25 and df['Number of Sunspots'] < 50]
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self):
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# The ambiguous error is because we are using 'and' to compare a series of booleans to a series of booleans
# python 'and' and only compare 1 boolean value to another

# %% [markdown]
# We can use
# > &  = AND logic
#
# > |  = OR logic

# %%
df[ (df['Number of Sunspots'] > 25)  & (df['Number of Sunspots'] < 50) ].head(10)
#this does not perminetly change any values
#printing df again we get the original
# Out:
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 12          12  1818      1   13                  37                 7.7
# 27          27  1818      1   28                  38                 7.8
# 46          46  1818      2   16                  28                 6.7
# 64          64  1818      3    6                  28                 6.7
# 68          68  1818      3   10                  48                 8.8
# 72          72  1818      3   14                  32                 7.1
# 74          74  1818      3   16                  47                 8.7
# 76          76  1818      3   18                  43                 8.3
# 86          86  1818      3   28                  48                 8.8
# 87          87  1818      3   29                  48                 8.8

# %%
df
# Out:
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 7               7  1818      1    8                  65                10.2
# 12             12  1818      1   13                  37                 7.7
# 16             16  1818      1   17                  77                11.1
# 17             17  1818      1   18                  98                12.6
# 18             18  1818      1   19                 105                13.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
# [70471 rows x 6 columns]

# %% [markdown]
# # Adding Columns

# %%
df['new'] = np.sqrt(df['Number of Sunspots'])
df.head(10)
# Out:
# /var/folders/_w/vh36344s2859llw5klmnx36w0000gn/T/ipykernel_84501/1352379765.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['new'] = np.sqrt(df['Number of Sunspots'])
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 7            7  1818      1    8                  65                10.2
# 12          12  1818      1   13                  37                 7.7
# 16          16  1818      1   17                  77                11.1
# 17          17  1818      1   18                  98                12.6
# 18          18  1818      1   19                 105                13.0
# 24          24  1818      1   25                  25                 6.3
# 27          27  1818      1   28                  38                 7.8
# 28          28  1818      1   29                  20                 5.7
# 33          33  1818      2    3                  17                 5.2
# 35          35  1818      2    5                  20                 5.7
#
#           new
# 7    8.062258
# 12   6.082763
# 16   8.774964
# 17   9.899495
# 18  10.246951
# 24   5.000000
# 27   6.164414
# 28   4.472136
# 33   4.123106
# 35   4.472136

# %%
df.drop('new',axis=1,inplace=True)
df
# Out:
# /var/folders/_w/vh36344s2859llw5klmnx36w0000gn/T/ipykernel_84501/3100320278.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('new',axis=1,inplace=True)
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation
# 7               7  1818      1    8                  65                10.2
# 12             12  1818      1   13                  37                 7.7
# 16             16  1818      1   17                  77                11.1
# 17             17  1818      1   18                  98                12.6
# 18             18  1818      1   19                 105                13.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
# [70471 rows x 6 columns]

# %% [markdown]
# # <span style="color:red">In Class</span>
#
# Create a new column named "Sunspot Number Error" that is defined as $$\frac{ \text{Standard Deviation} }{ \sqrt{ \text{Number of Sunspots} }}$$

# %%
#put code here
df['Sunspot Number Error'] = df['Standard Deviation']/np.sqrt(df['Number of Sunspots'])
df
# Out:
# /var/folders/_w/vh36344s2859llw5klmnx36w0000gn/T/ipykernel_84501/3736637829.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sunspot Number Error'] = df['Standard Deviation']/np.sqrt(df['Number of Sunspots'])
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 7               7  1818      1    8                  65                10.2
# 12             12  1818      1   13                  37                 7.7
# 16             16  1818      1   17                  77                11.1
# 17             17  1818      1   18                  98                12.6
# 18             18  1818      1   19                 105                13.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
#        Sunspot Number Error
# 7                  1.265154
# 12                 1.265872
# 16                 1.264962
# 17                 1.272792
# 18                 1.268670
# ...                     ...
# 73713                   NaN
# 73714                   NaN
# 73715                   NaN
# 73716                   NaN
# 73717                   NaN
#
# [70471 rows x 7 columns]

# %% [markdown]
# If we look at our Dataframe now, we will see that we have NA values.
# These come from deviding 0/0.

# %%
print(df.isna())
# Out:
#        Unnamed: 0   Year  Month    Day  Number of Sunspots  \
# 7           False  False  False  False               False
# 12          False  False  False  False               False
# 16          False  False  False  False               False
# 17          False  False  False  False               False
# 18          False  False  False  False               False
# ...           ...    ...    ...    ...                 ...
# 73713       False  False  False  False               False
# 73714       False  False  False  False               False
# 73715       False  False  False  False               False
# 73716       False  False  False  False               False
# 73717       False  False  False  False               False
#
#        Standard Deviation  Sunspot Number Error
# 7                   False                 False
# 12                  False                 False
# 16                  False                 False
# 17                  False                 False
# 18                  False                 False
# ...                   ...                   ...
# 73713               False                  True
# 73714               False                  True
# 73715               False                  True
# 73716               False                  True
# 73717               False                  True
#
# [70471 rows x 7 columns]

# %%
print('NAN')
df.loc[73713]
# Out:
# NAN
# Unnamed: 0              73713.0
# Year                     2019.0
# Month                      10.0
# Day                        27.0
# Number of Sunspots          0.0
# Standard Deviation          0.0
# Sunspot Number Error        NaN
# Name: 73713, dtype: float64

# %%
df.isna().sum()
# Out:
# Unnamed: 0                 0
# Year                       0
# Month                      0
# Day                        0
# Number of Sunspots         0
# Standard Deviation         0
# Sunspot Number Error    2517
# dtype: int64

# %% [markdown]
# We can set the NA values to anything we want. Here we will set them to '0'

# %%
df.fillna(0.0,inplace=True)

print(df.isna().sum())

print(df.loc[73713])
# Out:
# Unnamed: 0              0
# Year                    0
# Month                   0
# Day                     0
# Number of Sunspots      0
# Standard Deviation      0
# Sunspot Number Error    0
# dtype: int64
# Unnamed: 0              73713.0
# Year                     2019.0
# Month                      10.0
# Day                        27.0
# Number of Sunspots          0.0
# Standard Deviation          0.0
# Sunspot Number Error        0.0
# Name: 73713, dtype: float64
# /var/folders/_w/vh36344s2859llw5klmnx36w0000gn/T/ipykernel_84501/2719442779.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.fillna(0.0,inplace=True)

# %% [markdown]
# Similar to NA, by dividing a number/0, we generat an infinity value.

# %%
print('inf')
df.loc[53:57]
# Out:
# inf
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 53          53  1818      2   23                   0                 2.0
# 55          55  1818      2   25                   0                 2.0
# 56          56  1818      2   26                   0                 2.0
# 57          57  1818      2   27                   0                 2.0
#
#     Sunspot Number Error
# 53                   inf
# 55                   inf
# 56                   inf
# 57                   inf

# %%
df.isin([np.inf, -np.inf]).sum()
# Out:
# Unnamed: 0                 0
# Year                       0
# Month                      0
# Day                        0
# Number of Sunspots         0
# Standard Deviation         0
# Sunspot Number Error    8584
# dtype: int64

# %% [markdown]
# We can use
# > df.replace( array of values to replace, new value)
#
# to replace specific values

# %%
df.replace([np.inf,-np.inf],0,inplace=True)
df.loc[53:57]
# Out:
# /var/folders/_w/vh36344s2859llw5klmnx36w0000gn/T/ipykernel_84501/706409874.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.replace([np.inf,-np.inf],0,inplace=True)
#     Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 53          53  1818      2   23                   0                 2.0
# 55          55  1818      2   25                   0                 2.0
# 56          56  1818      2   26                   0                 2.0
# 57          57  1818      2   27                   0                 2.0
#
#     Sunspot Number Error
# 53                   0.0
# 55                   0.0
# 56                   0.0
# 57                   0.0

# %% [markdown]
# ## Groupby
#
# * Allows you to group together rows based off a column and then perform aggergate functions on them.
# * Aggergate function takes many values and returns one value (e.g. mean, sum, std, ...)
#
# ![groupby.png](attachment:groupby.png)

# %%
df
# Out:
#        Unnamed: 0  Year  Month  Day  Number of Sunspots  Standard Deviation  \
# 7               7  1818      1    8                  65                10.2
# 12             12  1818      1   13                  37                 7.7
# 16             16  1818      1   17                  77                11.1
# 17             17  1818      1   18                  98                12.6
# 18             18  1818      1   19                 105                13.0
# ...           ...   ...    ...  ...                 ...                 ...
# 73713       73713  2019     10   27                   0                 0.0
# 73714       73714  2019     10   28                   0                 0.0
# 73715       73715  2019     10   29                   0                 0.0
# 73716       73716  2019     10   30                   0                 0.0
# 73717       73717  2019     10   31                   0                 0.0
#
#        Sunspot Number Error
# 7                  1.265154
# 12                 1.265872
# 16                 1.264962
# 17                 1.272792
# 18                 1.268670
# ...                     ...
# 73713              0.000000
# 73714              0.000000
# 73715              0.000000
# 73716              0.000000
# 73717              0.000000
#
# [70471 rows x 7 columns]

# %%
df.groupby('Year').mean()
# Out:
#         Unnamed: 0     Month        Day  Number of Sunspots  \
# Year
# 1818    185.319249  6.638498  15.727700           52.938967
# 1819    555.060241  6.807229  15.333333           38.534137
# 1820    910.500000  6.459821  15.397321           24.232143
# 1821   1292.391447  7.006579  15.539474            9.180921
# 1822   1644.405099  6.572238  15.699717            6.254958
# ...            ...       ...        ...                 ...
# 2015  72135.000000  6.526027  15.720548           69.816438
# 2016  72500.500000  6.513661  15.756831           39.822404
# 2017  72866.000000  6.526027  15.720548           21.739726
# 2018  73231.000000  6.526027  15.720548            6.972603
# 2019  73565.500000  5.526316  15.713816            4.157895
#
#       Standard Deviation  Sunspot Number Error
# Year
# 1818            8.654460              1.182542
# 1819            7.119277              0.955278
# 1820            5.411607              0.699490
# 1821            3.417434              0.336688
# 1822            2.933994              0.207765
# ...                  ...                   ...
# 2015            5.198082              0.605304
# 2016            3.198907              0.493091
# 2017            1.776712              0.328374
# 2018            0.680274              0.171238
# 2019            0.278289              0.072957
#
# [202 rows x 6 columns]
